# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics

# Example data for income and expenses
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
income = [4500, 4800, 4700, 5000, 5200, 5100, 5300, 5400, 5500, 5600, 5700, 5800]
expenses = [3500, 3200, 3300, 3600, 3700, 3400, 3900, 4000, 4100, 4300, 4400, 4500]
savings = [i - e for i, e in zip(income, expenses)]

# %%
# Plot for income by month
plt.figure(figsize=(10, 6))
plt.plot(months, income, marker='o', color='b', label='Income')
plt.title('Income by Month')
plt.xlabel('Months')
plt.ylabel('Income')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Pie chart for monthly savings contribution to total savings
plt.figure(figsize=(8, 8))
colors = plt.cm.Paired(np.linspace(0, 1, len(months)))
plt.pie(savings, labels=months, colors=colors, autopct='%1.1f%%')
plt.title('Monthly Savings Contribution to Total Savings')
plt.show()

# %%
# Average income for each quarter
quarter1 = income[:3]
quarter2 = income[3:6]
quarter3 = income[6:9]
quarter4 = income[9:12]

avg_income_q1 = statistics.mean(quarter1)
avg_income_q2 = statistics.mean(quarter2)
avg_income_q3 = statistics.mean(quarter3)
avg_income_q4 = statistics.mean(quarter4)

# %%
# Output average income for each quarter
print(f"Average income for Q1: {avg_income_q1}")
print(f"Average income for Q2: {avg_income_q2}")
print(f"Average income for Q3: {avg_income_q3}")
print(f"Average income for Q4: {avg_income_q4}")
# Out:
# Average income for Q1: 4666.666666666667
# Average income for Q2: 5100
# Average income for Q3: 5400
# Average income for Q4: 5700
